# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/automatic-adventure/blob/main/Untitled70.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.DataFrame({'key':['b','b','a','c','a'],
                  'a1':range(5),
                  'b1':range(5,10)})
df1
# Out:
#   key  a1  b1
# 0   b   0   5
# 1   b   1   6
# 2   a   2   7
# 3   c   3   8
# 4   a   4   9

# %%
df2=pd.DataFrame({
    "key":['a','b','a'],
    "a2":range(3),
    "b2:":range(3,6)
})
df2
# Out:
#   key  a2  b2:
# 0   a   0    3
# 1   b   1    4
# 2   a   2    5

# %%
pd.merge(df1,df2,on='key')[['key','a1','a2']]
# Out:
#   key  a1  a2
# 0   b   0   1
# 1   b   1   1
# 2   a   2   0
# 3   a   2   2
# 4   a   4   0
# 5   a   4   2
